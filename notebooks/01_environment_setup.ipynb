# %% [markdown]
# # Intelligent Login Risk Analyzer
# ## Notebook 01: Environment Setup
#
# This notebook initializes the environment, imports required libraries, and loads the dataset for further analysis.

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# In this step, we import all necessary Python libraries for data analysis and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2: Check Library Versions
#
# Checking library versions ensures reproducibility and compatibility of the project.

# %% [markdown]
# print("Pandas version:", pd.__version__)
# print("NumPy version:", np.__version__)

# %%
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.1
# NumPy version: 2.4.3

# %% [markdown]
# ## Step 3: Load Dataset
#
# In this step, we load the login dataset from the data folder into a pandas DataFrame.

# %%
df = pd.read_excel('../data/dummy_login_dataset_300_rows.xlsx')
df.head()
# Out:
#      user   time               ip  location   device   status
# 0  user15  23:27    111.63.15.123     India     Edge   failed
# 1   user6  04:44   160.179.176.83  Rajshahi   Chrome   failed
# 2   user1  04:27    22.83.109.113    Sylhet  Firefox   failed
# 3  user14  17:16      15.4.242.67    Khulna   Chrome  success
# 4   user9  08:56  216.156.140.216       USA   Mobile   failed

# %% [markdown]
# ## Step 4: Inspect Dataset Structure
#
# In this step, we examine the dataset structure, column names, data types, and number of non-null values.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user      300 non-null    str
#  1   time      300 non-null    str
#  2   ip        300 non-null    str
#  3   location  300 non-null    str
#  4   device    300 non-null    str
#  5   status    300 non-null    str
# dtypes: str(6)
# memory usage: 14.2 KB

# %% [markdown]
# ## Step 5: Check Missing Values
#
# Here, we check whether the dataset contains any missing values in each column.

# %%
df.isnull().sum()
# Out:
# user        0
# time        0
# ip          0
# location    0
# device      0
# status      0
# dtype: int64

# %% [markdown]
# ## Step 6: Check Dataset Size
#
# This step shows the number of rows and columns in the dataset.

# %% [markdown]
# print("Dataset shape:", df.shape)

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (300, 6)

# %% [markdown]
# ## Step 7: View Column Names
#
# This step lists all column names in the dataset for quick reference.

# %%
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['user', 'time', 'ip', 'location', 'device', 'status']

# %% [markdown]
# ## Summary
#
# In this notebook, we successfully:
# - imported the required libraries
# - checked basic package versions
# - loaded the login dataset
# - inspected the dataset structure
# - checked for missing values
# - reviewed dataset size and columns
#
# The dataset is now ready for detailed exploration in the next notebook.
